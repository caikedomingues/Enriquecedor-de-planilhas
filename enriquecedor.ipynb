# %%
import openpyxl

import requests

import os

# %%
cnpj = "04.012.485/0001-94"

cnpj_limpo = cnpj.replace(".","").replace("/","").replace("-","")

link_api = f"https://receitaws.com.br/v1/cnpj/{cnpj_limpo}"

requisicao = requests.get(link_api)

print(cnpj_limpo)
print(requisicao)
# Out:
# 04012485000194
# <Response [200]>
