# %%
from openpyxl import load_workbook

import requests

import os

# %% [markdown]
# Criando as entradas de caminhos de diretórios

# %%
caminho_planilha_cnpjs = r"C:\Users\caike\Downloads\planilhas do enriquecedor"

caminho_planilhas_atualizadas = r"C:\Users\caike\Downloads\planilhas do enriquecedor atualizados"

# %% [markdown]
# Acessando a lista de arquivos de cada pasta

# %%
lista_planilha_cnpjs = os.listdir(caminho_planilha_cnpjs)

lista_planilha_cnpjs
# Out:
# ['lista 2.xlsx', 'lista1.xlsx']

# %%
lista_planilhas_atualizadas = os.listdir(caminho_planilhas_atualizadas)

lista_planilhas_atualizadas
# Out:
# []

# %% [markdown]
# Preparando o acesso as planilhas que devem ser atualizadas

# %%
for arquivo in lista_planilha_cnpjs:
    
    if "xlsx" in arquivo:
    
        planilha = load_workbook(f'{caminho_planilha_cnpjs}/{arquivo}')
    
        aba = planilha.active
        
        for lcoinha in aba.value:
    
    else:
        
        print(f"o arquivo {arquivo} não é um excel")
